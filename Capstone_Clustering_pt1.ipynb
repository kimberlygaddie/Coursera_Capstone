# %% [markdown]
# ## Week 3 Capstone Project - Clustering
# #### KGaddie

# %% [markdown]
# ### Step 1 - Scrape the following wikipedia page in order to obtain the data that is in the table of postal codes to transform the data into a pandas dataframe

# %%
## Library Setup

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
# Gathering Data from Webpage

wikipedia='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wiki=requests.get(wikipedia).text

#Beautiful Soup is now used to parse the codes for use
soup = BeautifulSoup(raw_wiki,'xml')

# %%
#Extract data from webpage

table = soup.find('table')

Postcode = []
Borough = []
Neighbourhood = []

for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
        if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'):
            
            continue
            
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            
            continue
    except:
        
        pass
    
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        
        continue

    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)
    
    unique_p = set(Postcode)
print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []


for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)
# Out:
# num of unique Postal codes: 77

# %%
#Printing the Requested Dataframe

toronto_dict = {'Postcode':Postcode_u, 'Borough':Borough_u, 'Neighbourhood':Neighbourhood_u}
df_toronto = pd.DataFrame.from_dict(toronto_dict)
df_toronto.to_csv('toronto_part1.csv')
df_toronto.head(14)
# Out:
#    Postcode           Borough  \
# 0       M8Y         Etobicoke
# 1       M1L       Scarborough
# 2       M4W  Downtown Toronto
# 3       M8Z         Etobicoke
# 4       M8V         Etobicoke
# 5       M6A        North York
# 6       M6M              York
# 7       M2K        North York
# 8       M4L      East Toronto
# 9       M4G         East York
# 10      M2L        North York
# 11      M1K       Scarborough
# 12      M3K        North York
# 13      M4E      East Toronto
#
#                                         Neighbourhood
# 0   Humber Bay, Mimico NE, Old Mill South, The Que...
# 1                     Clairlea, Golden Mile, Oakridge
# 2                                            Rosedale
# 3                       Mimico NW, The Queensway West
# 4                                         New Toronto
# 5                    Lawrence Heights, Lawrence Manor
# 6               Keelesdale, Mount Dennis, Silverthorn
# 7                                     Bayview Village
# ...

# %%
df_toronto.shape
